# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure()
plt.hist(df['age'])
plt.title("Distribución de edades")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

plt.figure()
df['survived'].value_counts().plot(kind='bar')
plt.title("Supervivencia de pasajeros")
plt.xlabel("Sobrevivió (0 = No, 1 = Sí)")
plt.ylabel("Cantidad")
plt.show()

plt.figure()
plt.scatter(df['age'], df['fare'])
plt.title("Edad vs Tarifa")
plt.xlabel("Edad")
plt.ylabel("Tarifa")
plt.show()

plt.figure()
corr = df.corr(numeric_only=True)

plt.imshow(corr)
plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Mapa de calor de correlaciones")
plt.show()

# %% [markdown]
# ## Histograma:
#
# - La distribución de edades es asimétrica hacia la derecha
# - Había pasajeros menores de 5 y mayores de 60
# - La edad promedio de los pasajeros era de entre entre los 29 y 30 años
#
# ## Barras:
#
# - Mas de la mitad de los pasajeros no logró sobrevivio
# - La proporción de hombres supera el 50% del total
#
# ## Dispersión
#
# - Hay Bastantes tarifas bajas
# - No hay una relación fuerte entre edad y tarifa
#
# ## Corelaciones:
#
# - Algunas variables muestran correlación cercana a cero
# - No existen muchas variables altamente dependientes unas de otras.
